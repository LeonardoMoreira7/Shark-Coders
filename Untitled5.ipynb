# %%
from tkinter import *
from tkinter import messagebox

#--------------------------------------------------------------------------------------------------------------------
# cores

branco = '#ffffff'
azul = '#364a85'
vermelho = '#b53128'
amarelo = '#ffef08'

# Tela
root = Tk()
root.title("Agenda")
root.geometry("380x500+500+100")
root.wm_resizable(width=False, height=False)

# Labels e Entrys
lb_agenda = Label(root, text="Sharkcoders Python", font="Time 20", bg=amarelo, fg=vermelho, anchor="w", padx=10)
lb_agenda.place(width=380, height=50, x=0, y=0)

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 22
#      19 lb_agenda = Label(root, text="Sharkcoders Python", font="Time 20", bg=amarelo, fg=vermelho, anchor="w", padx=10)
#      20 lb_agenda.place(width=380, height=50, x=0, y=0)
# ---> 22 root.mainloop()
#
# File c:\Users\Utilizador\anaconda3\Lib\tkinter\__init__.py:1599, in Misc.mainloop(self, n)
#    1597 def mainloop(self, n=0):
#    1598     """Call the mainloop of Tk."""
# -> 1599     self.tk.mainloop(n)
#
# KeyboardInterrupt:
