# %%
from tkinker import *
root = Tk()
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from tkinker import *
#       2 root = Tk()
#       3 root.mainloop()
#
# ModuleNotFoundError: No module named 'tkinker'
